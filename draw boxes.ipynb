# %%
import cv2
import pandas as pd
from PIL import Image

# %%
full_labels = pd.read_csv('data/raccoon_labels.csv')

# %%
full_labels.head()
# Out:
#          filename  width  height   class  xmin  ymin  xmax  ymax
# 0  helmet-205.png    480     480  helmet    37   116    94   160
# 1  helmet-238.png    640     427  helmet   341    21   564   174
# 2  helmet-308.png    640     426  helmet   145   136   230   201
# 3   helmet-17.png    640     480  helmet   292   174   339   215
# 4  helmet-165.png    480     480  helmet   207    44   277   162

# %%
def draw_boxes(image_name):
    selected_value = full_labels[full_labels.filename == image_name]
    img = cv2.imread('images/{}'.format(image_name))
    for index, row in selected_value.iterrows():
        img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
    return img

# %%
Image.fromarray(draw_boxes('helmet-10.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FA4E105E0B8>

# %%
Image.fromarray(draw_boxes('helmet-210.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FA4E105E080>

# %%
Image.fromarray(draw_boxes('helmet-310.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=380x480 at 0x7FA4E105E400>

# %%
Image.fromarray(draw_boxes('helmet-56.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FA4E105E128>

# %%
Image.fromarray(draw_boxes('helmet-91.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FA4E105E470>

# %%
Image.fromarray(draw_boxes('helmet-100.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FA4E105E550>

# %%
Image.fromarray(draw_boxes('helmet-102.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FA4E105E630>

# %%
Image.fromarray(draw_boxes('helmet-104.png'))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FA4E105E7F0>
